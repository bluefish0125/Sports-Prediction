# %% [markdown]
# ## 1. Import Packages and Dataset

# %%
import pandas as pd
import numpy as np
import sklearn
import torch.nn as nn
import sklearn.model_selection
from sklearn import linear_model
pd.set_option('display.max_columns', None)

# %%
folder_path = "Processed/"
csv_path = "NBA_2018-2024.csv"
complete_path = folder_path + csv_path
df = pd.read_csv(complete_path, index_col=0)

# %%
# only select seasons not in 2024 because of our data
df = df[~df['season'].isin([2024,2018])]
df = df.reset_index(drop=True)

# %%
folder_path = "NBA/"
csv_path = "processed_cumulative_2018-2023.csv"
complete_path = folder_path + csv_path
nba = pd.read_csv(complete_path, index_col=0)

# %%
nba.rename(columns={'Date': 'date_next', 'Teams':'Teams_x'}, inplace=True)

# %% [markdown]
# ## 2. Feature Engineering

# %%
def add_target(team):
    team['target'] = team['won'].shift(-1)
    return team

# %%
def winrate(team):
    total = team['Wins'] + team['Losses']
    total_opp = team['Wins_opp'] + team['Losses_opp']
    team['winrate'] = team['Wins'] / total
    team['winrate_opp'] = team['Wins_opp'] / total_opp
    return team

# %%
def differential(team):
    team['differential'] = team['Total'] - team['Total_opp']
    return team

# %%
df = winrate(df)

# %%
df = differential(df)

# %%
df = df.groupby("Teams", group_keys=False).apply(add_target)
# Out:
# /var/folders/99/zv3w4flx1598dxlknc099kfr0000gn/T/ipykernel_75648/777679873.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby("Teams", group_keys=False).apply(add_target)

# %%
# can remove columns with 2
df.loc[pd.isnull(df['target']), 'target'] = 2

# %%
df['target'] = df['target'].astype(int)

# %%
removed = ['target', 'date', 'Teams_opp', 'Teams','season','won', 'Wins', 'Losses', 'Wins_opp', 'Losses_opp']

# %%
valid_columns = df.columns[~df.columns.isin(removed)]

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
df[valid_columns] = scaler.fit_transform(df[valid_columns])

# %%
def find_team_average_n(team, n):
    numeric_columns = team.select_dtypes(include=np.number)
    rolling = numeric_columns.rolling(n).mean()
    return rolling

# %%
def find_team_exp_average_5(team):
    numeric_columns = team.select_dtypes(include=np.number)
    rolling = numeric_columns.ewm(span=5, adjust=False).mean()
    return rolling

# %%
def find_team_exp_average_9(team):
    numeric_columns = team.select_dtypes(include=np.number)
    rolling = numeric_columns.ewm(span=9, adjust=False).mean()
    return rolling

# %%
def find_team_exp_average_12(team):
    numeric_columns = team.select_dtypes(include=np.number)
    rolling = numeric_columns.ewm(span=12, adjust=False).mean()
    return rolling

# %%
def find_team_average_15(team):
    numeric_columns = team.select_dtypes(include=np.number)
    rolling = numeric_columns.rolling(15).mean()
    return rolling

# %%
def find_team_average_10(team):
    numeric_columns = team.select_dtypes(include=np.number)
    rolling = numeric_columns.rolling(10).mean()
    return rolling

# %%
def find_team_average_5(team):
    numeric_columns = team.select_dtypes(include=np.number)
    rolling = numeric_columns.rolling(5).mean()
    return rolling

# %%
def find_team_average_3(team):
    numeric_columns = team.select_dtypes(include=np.number)
    rolling = numeric_columns.rolling(3).mean()
    return rolling

# %%
def ratio(data):
    columns = [col for col in data.columns if "_5" in col]
    for column in columns:
        col_name = column.rsplit('_', 1)[0]
        if (len(data[f'{col_name}_5']) == 0):
            continue
        data[f'{col_name}_5_10'] = data[f'{col_name}_5'] / data[f'{col_name}_10']
    return data

# %%
def rolling(data):
    df_rolling_3 = data[list(valid_columns) + ['Teams','won', "season"]]
    df_rolling_3 = df_rolling_3.groupby(['Teams', 'season'], group_keys = False).apply(find_team_average_3)
    df_rolling_5 = data[list(valid_columns) + ['Teams','won', "season"]]
    df_rolling_5 = df_rolling_5.groupby(['Teams', 'season'], group_keys = False).apply(find_team_average_5)
    df_rolling_10 = data[list(valid_columns) + ['Teams','won', "season"]]
    df_rolling_10 = df_rolling_10.groupby(['Teams', 'season'], group_keys = False).apply(find_team_average_10)
    df_rolling_15 = data[list(valid_columns) + ['Teams','won', "season"]]
    df_rolling_15 = df_rolling_15.groupby(['Teams', 'season'], group_keys = False).apply(find_team_average_15)
    df_exp_rolling_5 = data[list(valid_columns) + ['Teams','won', "season"]]
    df_exp_rolling_5 = df_exp_rolling_5.groupby(['Teams', 'season'], group_keys = False).apply(find_team_exp_average_5)
    df_exp_rolling_9 = data[list(valid_columns) + ['Teams','won', "season"]]
    df_exp_rolling_9 = df_exp_rolling_9.groupby(['Teams', 'season'], group_keys = False).apply(find_team_exp_average_9)
    df_exp_rolling_12 = data[list(valid_columns) + ['Teams','won', "season"]]
    df_exp_rolling_12 = df_exp_rolling_12.groupby(['Teams', 'season'], group_keys = False).apply(find_team_exp_average_12, include_groups=False)
    exp_rolling_columns_5 = [f"{col}_exp_5" for col in df_exp_rolling_5.columns]
    exp_rolling_columns_9 = [f"{col}_exp_9" for col in df_exp_rolling_9.columns]
    exp_rolling_columns_12 = [f"{col}_exp_12" for col in df_exp_rolling_12.columns]
    rolling_columns_15 = [f"{col}_15" for col in df_rolling_15.columns]
    rolling_columns_10 = [f"{col}_10" for col in df_rolling_10.columns]
    rolling_columns_5 = [f"{col}_5" for col in df_rolling_5.columns]
    rolling_columns_3 = [f"{col}_3" for col in df_rolling_3.columns]
    df_exp_rolling_12.columns = exp_rolling_columns_12
    df_exp_rolling_9.columns = exp_rolling_columns_9
    df_exp_rolling_5.columns = exp_rolling_columns_5
    df_rolling_15.columns = rolling_columns_15
    df_rolling_10.columns = rolling_columns_10
    df_rolling_5.columns = rolling_columns_5
    df_rolling_3.columns = rolling_columns_3
    df = pd.concat([data, df_rolling_3, df_rolling_5, df_rolling_10, df_rolling_15,df_exp_rolling_5,df_exp_rolling_9, df_exp_rolling_12], axis=1)
    # df_exp_rolling_5,df_exp_rolling_9, df_exp_rolling_12
    return df

# %%
df = rolling(df).copy()
# Out:
# /var/folders/99/zv3w4flx1598dxlknc099kfr0000gn/T/ipykernel_75648/2730748955.py:3: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_rolling_3 = df_rolling_3.groupby(['Teams', 'season'], group_keys = False).apply(find_team_average_3)
# /var/folders/99/zv3w4flx1598dxlknc099kfr0000gn/T/ipykernel_75648/2730748955.py:5: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_rolling_5 = df_rolling_5.groupby(['Teams', 'season'], group_keys = False).apply(find_team_average_5)
# /var/folders/99/zv3w4flx1598dxlknc099kfr0000gn/T/ipykernel_75648/2730748955.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_rolling_10 = df_rolling_10.groupby(['Teams', 'season'], group_keys = False).apply(find_team_average_10)
# /var/folders/99/zv3w4flx1598dxlknc099kfr0000gn/T/ipykernel_75648/2730748955.py:9: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_rolling_15 = df_rolling_15.groupby(['Teams', 'season'], group_keys = False).apply(find_team_average_15)
# /var/folders/99/zv3w4flx1598dxlknc099kfr0000gn/T/ipykernel_75648/2730748955.py:11: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_exp_rolling_5 = df_exp_rolling_5.groupby(['Teams', 'season'], group_keys = False).apply(find_team_exp_average_5)
# /var/folders/99/zv3w4flx1598dxlknc099kfr0000gn/T/ipykernel_75648/2730748955.py:13: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_exp_rolling_9 = df_exp_rolling_9.groupby(['Teams', 'season'], group_keys = False).apply(find_team_exp_average_9)

# %%
df = df.dropna()

# %%
def shift_col(team, col_name):
    next_col = team[col_name].shift(-1)
    return next_col

def add_col(df, col_name):
    return df.groupby("Teams", group_keys=False).apply(lambda x: shift_col(x, col_name))

# %%
df['home_next'] = add_col(df, 'home')
df['team_next_opp'] = add_col(df, 'Teams_opp')
df['date_next'] = add_col(df, 'date')
# Out:
# /var/folders/99/zv3w4flx1598dxlknc099kfr0000gn/T/ipykernel_75648/138724945.py:6: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby("Teams", group_keys=False).apply(lambda x: shift_col(x, col_name))
# /var/folders/99/zv3w4flx1598dxlknc099kfr0000gn/T/ipykernel_75648/138724945.py:6: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby("Teams", group_keys=False).apply(lambda x: shift_col(x, col_name))
# /var/folders/99/zv3w4flx1598dxlknc099kfr0000gn/T/ipykernel_75648/138724945.py:6: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby("Teams", group_keys=False).apply(lambda x: shift_col(x, col_name))

# %%
df = df.copy()

# %%
full = df.merge(df,
               left_on=['Teams', 'date_next'],
               right_on = ['team_next_opp', 'date_next'])

# %%
full = pd.merge(full, nba, on=['Teams_x', 'date_next'], how='left')

# %%
full = full.dropna()

# %%
full.shape
# Out:
# (9114, 2691)

# %%
disregard = list(full.columns[full.dtypes == 'object'])

# %%
disregard = disregard + ["home_opp_5_x","target_x","target_y", 
                         "Wins_x", "Losses_x", "Wins_opp_x", "Losses_opp_x", 
                         "season_x" , "won_x" , "home_5_x" ,"home_10_x" ,"season_5_x", 
                         "season_10_x" , "Wins_y" , "Losses_y" , "Wins_opp_y" , "Losses_opp_y" , 
                         "season_y" , "won_y" ,"home_5_y", "home_10_y","season_5_y", "season_10_y",
                         "home_opp_5_y", "home_opp_10_y"]

# %%
regard = full.columns[~full.columns.isin(disregard)]

# %%
full[regard]
# Out:
#       mp_x      fg_x     fga_x     fg%_x      3p_x     3pa_x     3p%_x  \
# 0     0.00  0.727273  0.516667  0.705742  0.407407  0.350000  0.447059
# 1     0.00  0.250000  0.483333  0.188995  0.259259  0.533333  0.179085
# 2     0.00  0.363636  0.400000  0.373206  0.037037  0.133333  0.117647
# 3     0.00  0.454545  0.516667  0.399522  0.407407  0.383333  0.414379
# 4     0.00  0.363636  0.416667  0.361244  0.222222  0.316667  0.260131
# ...    ...       ...       ...       ...       ...       ...       ...
# 9135  0.00  0.386364  0.416667  0.389952  0.407407  0.516667  0.313725
# 9136  0.00  0.477273  0.500000  0.437799  0.592593  0.750000  0.326797
# 9137  0.25  0.681818  0.483333  0.681818  0.296296  0.383333  0.295425
# 9138  0.00  0.545455  0.300000  0.686603  0.481481  0.566667  0.345098
# 9139  0.00  0.659091  0.533333  0.614833  0.407407  0.316667  0.484967
#
#           ft_x  fta_x     ft%_x     orb_x     drb_x     trb_x     ast_x  \
# 0     0.404762   0.42  0.674355  0.379310  0.659091  0.666667  0.619048
# 1     0.428571   0.46  0.648575  0.517241  0.272727  0.411765  0.285714
# 2     0.595238   0.60  0.720488  0.413793  0.431818  0.490196  0.238095
# 3     0.166667   0.18  0.582090  0.137931  0.363636  0.274510  0.333333
# 4     0.285714   0.32  0.592944  0.379310  0.477273  0.509804  0.190476
# ...        ...    ...       ...       ...       ...       ...       ...
# 9135  0.428571   0.46  0.648575  0.241379  0.409091  0.372549  0.333333
# 9136  0.190476   0.18  0.686567  0.241379  0.454545  0.411765  0.357143
# 9137  0.404762   0.48  0.564450  0.137931  0.409091  0.313725  0.571429
# ...                        ...                     ...
# 9135                      19.0                    15.0
# 9136                      24.0                     1.0
# 9137                      25.0                     8.0
# 9138                       5.0                     6.0
# 9139                      30.0                    22.0
#
#       OPP_FG3A_RANK_opponent  OPP_FG3_PCT_RANK_opponent  \
# 0                       16.0                        8.0
# 1                       25.0                       30.0
# 2                       15.0                       29.0
# 3                       29.0                       20.0
# 4                       18.0                       16.0
# ...                      ...                        ...
# 9135                    19.0                       14.0
# 9136                     2.0                        7.0
# 9137                    16.0                       10.0
# 9138                    17.0                        4.0
# 9139                     5.0                       30.0
#
#       OPP_FTM_RANK_opponent  OPP_FTA_RANK_opponent  OPP_FT_PCT_RANK_opponent  \
# 0                      18.0                   19.0                      12.0
# 1                      26.0                   27.0                       6.0
# 2                      27.0                   26.0                      23.0
# 3                      20.0                   16.0                      29.0
# 4                       4.0                    5.0                       1.0
# ...                     ...                    ...                       ...
# 9135                   22.0                   19.0                      25.0
# 9136                   25.0                   24.0                      15.0
# 9137                   18.0                   13.0                      30.0
# 9138                    2.0                    4.0                       3.0
# 9139                   11.0                   16.0                       5.0
#
#       OPP_OREB_RANK_opponent  OPP_DREB_RANK_opponent  OPP_REB_RANK_opponent  \
# 0                       10.0                     8.0                    7.0
# 1                       22.0                    27.0                   26.0
# 2                       25.0                    21.0                   22.0
# 3                       29.0                    30.0                   30.0
# 4                       22.0                    11.0                   16.0
# ...                      ...                     ...                    ...
# 9135                    22.0                    30.0                   29.0
# 9136                    10.0                    28.0                   23.0
# 9137                    17.0                    21.0                   19.0
# 9138                     8.0                    26.0                   18.0
# 9139                    18.0                    27.0                   26.0
#
#       OPP_AST_RANK_opponent  OPP_TOV_RANK_opponent  OPP_STL_RANK_opponent  \
# 0                      18.0                   16.0                   19.0
# 1                      30.0                    1.0                   30.0
# 2                      25.0                    5.0                   14.0
# 3                      29.0                    8.0                   28.0
# 4                      16.0                   29.0                    9.0
# ...                     ...                    ...                    ...
# 9135                   21.0                   12.0                   10.0
# 9136                    8.0                   23.0                    3.0
# 9137                   22.0                   16.0                   18.0
# 9138                    2.0                   26.0                    5.0
# 9139                   29.0                   17.0                   28.0
#
#       OPP_BLK_RANK_opponent  OPP_BLKA_RANK_opponent  OPP_PF_RANK_opponent  \
# 0                      27.0                    21.0                  20.0
# 1                      20.0                    13.0                  28.0
# 2                      13.0                     5.0                  26.0
# 3                      30.0                    16.0                   9.0
# 4                      26.0                    22.0                  12.0
# ...                     ...                     ...                   ...
# 9135                   29.0                     8.0                  18.0
# 9136                    2.0                    28.0                  30.0
# 9137                   21.0                    12.0                  12.0
# 9138                    4.0                     6.0                   6.0
# 9139                   25.0                    26.0                   2.0
#
#       OPP_PFD1_opponent  OPP_PTS_RANK_opponent  PLUS_MINUS_RANK_opponent  \
# 0                  15.0                   14.0                       4.0
# 1                   5.0                   26.0                      29.0
# 2                   7.0                   23.0                      25.0
# 3                  13.0                   29.0                      29.0
# 4                  23.0                   16.0                       3.0
# ...                 ...                    ...                       ...
# 9135               14.0                   22.0                      27.0
# 9136                8.0                   16.0                      19.0
# 9137               25.0                   26.0                      18.0
# 9138               24.0                    5.0                       1.0
# 9139               19.0                   30.0                      30.0
#
#       DEF_RATING_defense  DREB_defense  DREB_PCT_defense  STL_defense  \
# 0                  105.4         560.0             0.761        138.0
# 1                  109.9         549.0             0.703        139.0
# 2                  112.4         509.0             0.682        131.0
# 3                  110.9         578.0             0.710        130.0
# 4                  105.8         638.0             0.741         94.0
# ...                  ...           ...               ...          ...
# 9135               114.7        2751.0             0.717        634.0
# 9136               116.1        2556.0             0.717        514.0
# 9137               115.4        2719.0             0.717        580.0
# 9138               110.6        2921.0             0.746        521.0
# 9139               119.6        2619.0             0.709        572.0
#
#       BLK_defense  OPP_PTS_OFF_TOV_defense  OPP_PTS_2ND_CHANCE_defense  \
# 0            79.0                    266.0                       201.0
# 1            90.0                    371.0                       267.0
# 2           101.0                    300.0                       249.0
# 3            84.0                    315.0                       216.0
# 4            75.0                    237.0                       216.0
# ...           ...                      ...                         ...
# 9135        425.0                   1389.0                      1170.0
# 9136        304.0                   1229.0                      1185.0
# 9137        401.0                   1284.0                      1153.0
# 9138        430.0                   1260.0                      1044.0
# 9139        322.0                   1558.0                      1202.0
#
#       OPP_PTS_FB_defense  OPP_PTS_PAINT_defense  GP_RANK_defense  \
# 0                  207.0                  764.0              6.0
# 1                  262.0                  734.0              6.0
# 2                  239.0                  748.0              9.0
# 3                  238.0                  784.0              2.0
# 4                  229.0                  772.0              9.0
# ...                  ...                    ...              ...
# 9135              1002.0                 4330.0              1.0
# 9136              1090.0                 4190.0              1.0
# 9137              1259.0                 4484.0              1.0
# 9138              1082.0                 4010.0              1.0
# 9139              1257.0                 4646.0              1.0
#
#       W_RANK_defense  L_RANK_defense  W_PCT_RANK_defense  MIN_RANK_defense  \
# 0                5.0             8.0                 8.0               8.0
# 1               28.0            29.0                29.0               9.0
# 2               25.0            25.0                25.0              10.0
# 3               26.0            29.0                27.0               2.0
# 4                3.0             3.0                 3.0              10.0
# ...              ...             ...                 ...               ...
# 9135            27.0            27.0                27.0              12.0
# 9136            21.0            21.0                21.0               3.0
# 9137            17.0            17.0                17.0               8.0
# 9138             2.0             2.0                 2.0               1.0
# 9139            28.0            28.0                28.0               8.0
#
#       DEF_RATING_RANK_defense  DREB_RANK_defense  DREB_PCT_RANK_defense  \
# 0                         6.0                9.0                    3.0
# 1                        22.0               12.0                   27.0
# 2                        29.0               24.0                   30.0
# 3                        26.0                8.0                   22.0
# 4                         8.0                3.0                    9.0
# ...                       ...                ...                    ...
# 9135                     20.0               10.0                   19.0
# 9136                     25.0               27.0                   17.0
# 9137                     22.0               12.0                   18.0
# 9138                      2.0                3.0                    1.0
# 9139                     30.0               23.0                   24.0
#
#       STL_RANK_defense  BLK_RANK_defense  OPP_PTS_OFF_TOV_RANK_defense  \
# 0                  6.0              21.0                          16.0
# 1                  5.0              13.0                          30.0
# 2                 12.0               5.0                          22.0
# 3                 11.0              16.0                          27.0
# 4                 28.0              22.0                           6.0
# ...                ...               ...                           ...
# 9135               9.0               8.0                          16.0
# 9136              29.0              28.0                           3.0
# 9137              18.0              12.0                           9.0
# 9138              27.0               6.0                           5.0
# 9139              22.0              26.0                          28.0
#
#       OPP_PTS_2ND_CHANCE_RANK_defense  OPP_PTS_FB_RANK_defense  \
# 0                                13.0                     11.0
# 1                                28.0                     28.0
# 2                                24.0                     22.0
# 3                                19.0                     24.0
# 4                                16.0                     16.0
# ...                               ...                      ...
# 9135                             21.0                      3.0
# 9136                             23.0                     11.0
# 9137                             20.0                     26.0
# 9138                              7.0                     10.0
# 9139                             26.0                     24.0
#
#       OPP_PTS_PAINT_RANK_defense
# 0                           18.0
# 1                           14.0
# 2                           15.0
# 3                           20.0
# 4                           18.0
# ...                          ...
# 9135                        22.0
# 9136                        18.0
# 9137                        29.0
# 9138                         9.0
# 9139                        30.0
#
# [9114 rows x 2657 columns]

# %% [markdown]
# ## 3. Modeling

# %%
from sklearn.model_selection import TimeSeriesSplit
from sklearn.feature_selection import SequentialFeatureSelector
from sklearn.linear_model import RidgeClassifier

rr = RidgeClassifier(alpha=1)
split = TimeSeriesSplit(n_splits=3)

# can also try direction backward
sfs = SequentialFeatureSelector(rr, n_features_to_select = 70, direction='forward', cv=split)

# %%
sfs.fit(full[regard], full['target_x'])
# Out:
# SequentialFeatureSelector(cv=TimeSeriesSplit(gap=0, max_train_size=None, n_splits=3, test_size=None),
#                           estimator=RidgeClassifier(alpha=1),
#                           n_features_to_select=70)

# %%
predictors = list(regard[sfs.get_support()])

# %%
predictors
# Out:
# ['3par_x',
#  'usg%_x',
#  'orbmaxes_x',
#  'usg%_opp_x',
#  'ft%maxes_opp_x',
#  'winrate_x',
#  'usg%_3_x',
#  'usg%_opp_3_x',
#  'stlmaxes_opp_3_x',
#  'winrate_3_x',
#  'blk%_5_x',
#  'usg%_5_x',
#  'usg%_opp_5_x',
#  '3pamaxes_opp_5_x',
#  'drb_10_x',
#  'tov_10_x',
#  'usg%_10_x',
#  '3pamaxes_10_x',
#  '3p%maxes_10_x',
#  'ft%maxes_10_x',
#  'ft%_opp_10_x',
#  'usg%_opp_10_x',
#  'usg%_15_x',
#  'usg%_opp_15_x',
#  'usg%_exp_5_x',
#  'usg%_opp_exp_5_x',
#  'tovmaxes_opp_exp_5_x',
#  'winrate_exp_5_x',
#  'usg%_exp_9_x',
#  'usg%_opp_exp_9_x',
#  'tov_exp_12_x',
#  'efg%_exp_12_x',
#  'usg%_exp_12_x',
#  'usg%_opp_exp_12_x',
#  '+/-maxes_opp_exp_12_x',
#  'usg%_y',
#  'usg%_opp_y',
#  'usg%_3_y',
#  'ast%_opp_3_y',
#  'usg%_opp_3_y',
#  'stl%maxes_opp_3_y',
#  'usg%_5_y',
#  'ft%maxes_5_y',
#  'usg%_opp_5_y',
#  'usg%_10_y',
#  'usg%_opp_10_y',
#  'usg%_15_y',
#  'ftrmaxes_15_y',
#  'stl%_opp_15_y',
#  'usg%_opp_15_y',
#  'usg%_exp_5_y',
#  'ft%_opp_exp_5_y',
#  'usg%_opp_exp_5_y',
#  'usg%_exp_9_y',
#  'pf_opp_exp_9_y',
#  'usg%_opp_exp_9_y',
#  '3p%maxes_opp_exp_9_y',
#  'usg%_exp_12_y',
#  'usg%_opp_exp_12_y',
#  'W_PCT_base',
#  'W_PCT_RANK_base',
#  'E_NET_RATING_advanced',
#  'W_PCT_RANK_advanced',
#  'NET_RATING_RANK_advanced',
#  'W_PCT_RANK_four_factors',
#  'W_PCT_RANK_scoring',
#  'OPP_FG_PCT_opponent',
#  'W_PCT_RANK_opponent',
#  'OPP_FG3A_RANK_opponent',
#  'W_PCT_RANK_defense']

# %%
from sklearn.model_selection import train_test_split, TimeSeriesSplit
from sklearn.metrics import accuracy_score,f1_score
import pickle 

def backtest(data, model, predictors, true):
    X = data[predictors]
    y = data['target_x']
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, shuffle=False, test_size=0.20, random_state=42)
    
    model.fit(X_train, y_train)
    predictions = model.predict(X_test)
    result = pd.Series(predictions, index = y_test.index)
    
    final = pd.concat([y_test, result], axis=1)
    final.columns = ['Actual', 'Predictions']
    if (True):
        with open('70_86.5%_ridge_classifier_2019-2023.pkl', 'wb') as f:
            pickle.dump(model, f)
    print(model.coef_)
    return final

# %%
final = backtest(full, rr, predictors, True)
# Out:
# [[-2.50651959e-02  0.00000000e+00  8.26782929e-03  0.00000000e+00
#    1.22282005e-01 -1.00041461e+01  0.00000000e+00  0.00000000e+00
#    8.94625566e-02 -4.13117904e+00  1.33515130e-01  0.00000000e+00
#    0.00000000e+00 -1.16700651e-01  1.54179254e-01 -4.06250337e-01
#    0.00000000e+00  9.11920860e-02  7.91367834e-02  1.03277729e-01
#   -7.05367763e-02  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00  0.00000000e+00  1.66809344e-01 -3.62759979e+00
#    0.00000000e+00  0.00000000e+00  1.90574836e-01 -4.41656270e-01
#    0.00000000e+00  0.00000000e+00  1.31577303e+00  0.00000000e+00
#    0.00000000e+00  0.00000000e+00  7.52033425e-02  0.00000000e+00
#   -1.25985034e-01  0.00000000e+00  5.48171029e-03  0.00000000e+00
#    0.00000000e+00  0.00000000e+00  0.00000000e+00 -4.21166482e-01
#    1.21313223e+00  0.00000000e+00  0.00000000e+00  2.09535549e-02
#    0.00000000e+00  0.00000000e+00 -3.84821713e-02  0.00000000e+00
#    8.58584338e-02  0.00000000e+00  0.00000000e+00  1.62814787e+01
#   -6.97166922e-03  5.56371202e-02 -6.97166922e-03  8.48406666e-03
#   -6.97166922e-03 -6.97166922e-03  1.71304243e-01 -6.97166922e-03
#   -2.24886029e-04 -6.97166922e-03]]

# %%
final
# Out:
#       Actual  Predictions
# 7291       0            0
# 7292       1            1
# 7293       0            0
# 7294       1            1
# 7295       0            0
# ...      ...          ...
# 9135       1            0
# 9136       0            0
# 9137       0            0
# 9138       1            1
# 9139       1            0
#
# [1823 rows x 2 columns]

# %%
accuracy = accuracy_score(final['Actual'], final['Predictions'])
f1 = f1_score(final['Actual'], final['Predictions'])

# %%
print("The accuracy is: ", accuracy)
print("The f1 is: ", f1)
# Out:
# The accuracy is:  0.8650575973669775
# The f1 is:  0.8616422947131608

# %%
# save the predictors 
file_path = 'Predictions/Factors/70_86.5%_predictors_ridge_classifier_2019-2023.txt'
with open(file_path, 'w') as f:
    for predictor in predictors:
        f.write(f'{predictor},')

# %%
def backtest_time_series(data, model, predictors, true):
    X = data[predictors]
    y = data['target_x']
    
    test_size = len(y) // 4
    
    tscv = TimeSeriesSplit(n_splits=4, test_size=test_size)
    
    for train_index, test_index in tscv.split(X):
        X_train, X_test = X.iloc[train_index], X.iloc[test_index]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]
        
        model.fit(X_train, y_train)
        predictions = model.predict(X_test)
        result = pd.Series(predictions, index=y_test.index)
        
        final = pd.concat([y_test, result], axis=1)
        final.columns = ['Actual', 'Predictions']
        
        
    if (True):
        with open('time_series_ridge_classifier_2018-2024.pkl', 'wb') as f:
            pickle.dump(model, f)
    return final

# %%
final_time_series = backtest_time_series(full, rr, predictors, False)

# %%
accuracy_time = accuracy_score(final_time_series['Actual'], final_time_series['Predictions'])
f1_time = f1_score(final_time_series['Actual'], final_time_series['Predictions'])

# %%
print("The accuracy is: ", accuracy_time)
print("The f1 is: ", f1_time)
# Out:
# The accuracy is:  0.8542581211589113
# The f1 is:  0.8527062999112689
