# %% [markdown]
# - [1. Importing Packages and Dataset](#1)
# - [2. Assembling the Dataset and Explore Datasets](#2)
# - [3. and Preprocessing for Modeling](#3)
# - [4. Modeling](#4)

# %% [markdown]
# ## 1. Importing Packages and Dataset <a id='1'></a>

# %%
import pandas as pd
import numpy as np
# import matplotlib.pyplot as plt
# import seaborn as sns

# Use TensorFlow's Keras API
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, LSTM, Dropout, Embedding, Bidirectional, Input, Lambda, Reshape
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.utils import to_categorical
import tensorflow as tf
import markovify
import pronouncing
import os

import re
import random

import torch
random.seed(0)
np.random.seed(0)
tf.random.set_seed(0)
# Out:
# 2024-03-21 10:53:18.067362: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
game_data_path = '/Users/liqingyang/Documents/GitHub/sports_trading/sports_betting/data/NBA_2018_2024.csv'
pd.read_csv(game_data_path)
# Out:
#        Unnamed: 0     mp    fg    fga    fg%    3p   3pa    3p%    ft   fta  \
# 0               0  240.0  36.0   88.0  0.409   8.0  32.0  0.250  19.0  25.0
# 1               1  240.0  38.0   83.0  0.458   5.0  22.0  0.227  21.0  25.0
# 2               2  240.0  47.0   97.0  0.485  15.0  41.0  0.366  13.0  19.0
# 3               3  240.0  43.0   80.0  0.538  16.0  30.0  0.533  19.0  21.0
# 4               4  240.0  37.0   85.0  0.435   8.0  19.0  0.421  17.0  23.0
# ...           ...    ...   ...    ...    ...   ...   ...    ...   ...   ...
# 15959          67  265.0  47.0  102.0  0.461   8.0  31.0  0.258  13.0  19.0
# 15960          68  240.0  51.0   87.0  0.586  14.0  33.0  0.424  13.0  15.0
# 15961          69  240.0  51.0   94.0  0.543  24.0  41.0  0.585  14.0  14.0
# 15962          70  240.0  28.0   74.0  0.378  11.0  36.0  0.306  26.0  29.0
# 15963          71  240.0  43.0   85.0  0.506  11.0  36.0  0.306  14.0  20.0
#
#        ...  TOV%_opp  ORB%_opp  FT/FGA_opp  ORtg_opp  Wins_opp  Losses_opp  \
# 0      ...      15.3      19.6       0.253     102.7         1           0
# 1      ...       9.2      18.0       0.216      99.7         0           1
# 2      ...      16.0      15.4       0.238     118.6         0           1
# 3      ...      10.2      22.2       0.134     119.6         1           0
# 4      ...      10.2      27.9       0.191     113.3         1           0
# ...    ...       ...       ...         ...       ...       ...         ...
# 15959  ...      13.5      26.0       0.212     111.6        15          53
# 15960  ...       9.1      23.8       0.149     143.4        44          24
# 15961  ...      11.4      21.9       0.149     132.2        39          29
# 15962  ...      13.6      25.0       0.131     121.6        30          37
# 15963  ...      16.6      27.5       0.167     102.3        23          45
#
#        home_opp  season                 date    won
# 0             1    2018           2017-10-17  False
# 1             0    2018           2017-10-17   True
# 2             1    2018           2017-10-17   True
# 3             0    2018           2017-10-17  False
# 4             1    2018           2017-10-18  False
# ...         ...     ...                  ...    ...
# 15959         1    2024  2024-03-17 00:00:00  False
# 15960         1    2024  2024-03-17 00:00:00  False
# 15961         0    2024  2024-03-17 00:00:00   True
# 15962         0    2024  2024-03-17 00:00:00  False
# 15963         0    2024  2024-03-17 00:00:00   True
#
# [15964 rows x 158 columns]
